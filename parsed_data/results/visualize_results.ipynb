# %%
import pandas as pd

# %%
df = pd.read_csv("/home/juuso/Documents/gradu/parsed_data/results/ppo_mm_full_orderbook.csv", header=None)
df.columns = ["quote_asset", "base_asset", "mid_price", "bid", "bid_size", "ask", "ask_size", "exec_market_buy", "exec_market_sell", "exec_limit_buy", "exec_limit_sell"]
df['value'] = df['quote_asset'] + df['base_asset'] * df['mid_price']
df
# Out:
#       quote_asset  base_asset  mid_price       bid  bid_size       ask  \
# 0     1000.000000  833.333333    1.24355  0.635545  0.000000  0.000000
# 1     1000.000000  833.333333    1.24355  1.549135  0.000000  0.000000
# 2     1000.000000  833.333333    1.24355  0.771093  0.000000  1.417571
# 3     1000.000000  833.333333    1.24350  0.000000  0.439514  0.098335
# 4     1000.202549  833.157615    1.24345  0.667584  0.293742  0.000000
# ...           ...         ...        ...       ...       ...       ...
# 2564  1071.176578    1.982657    1.24175  0.404302  0.653630  0.302116
# 2565  1071.176578    1.982657    1.24175  0.000000  1.083108  0.045316
# 2566  1071.176578    1.979233    1.24175  0.738763  0.069274  0.000000
# 2567  1071.176578    0.809972    1.24175  0.459621  0.000000  0.000000
# 2568     0.000000    0.000000    1.24175  0.019877  0.597141  0.000000
#
#       ask_size  exec_market_buy  exec_market_sell  exec_limit_buy  \
# ...
